# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def plot(file_path):
    df = pd.read_csv(file_path)

    # Rename columns for easier handling
    df.columns = ["File Name", "BLEU", "ROUGE-L", "METEOR"]

    # Summary statistics
    print(df.describe())

    # Pairplot to visualize correlations
    sns.pairplot(df[["BLEU", "ROUGE-L", "METEOR"]], kind="reg")
    plt.suptitle("Pairplot of BLEU, ROUGE-L, and METEOR Scores", y=1.02)
    plt.show()

    # Correlation heatmap
    plt.figure(figsize=(6, 4))
    sns.heatmap(df[["BLEU", "ROUGE-L", "METEOR"]].corr(), annot=True, cmap="coolwarm", fmt=".2f")
    plt.title("Correlation Heatmap of Scores")
    plt.show()

    # Distribution plots
    plt.figure(figsize=(12, 4))
    for i, metric in enumerate(["BLEU", "ROUGE-L", "METEOR"]):
        plt.subplot(1, 3, i + 1)
        sns.histplot(df[metric], bins=10, kde=True)
        plt.title(f"Distribution of {metric} Scores")
    plt.tight_layout()
    plt.show()

# %%
# Section-wise Review by All Reviewers
plot("../csv/section_language_scores.csv")
# Out:
#                BLEU    ROUGE-L     METEOR
# count  1.000000e+01  10.000000  10.000000
# mean   2.248694e-04   0.064487   0.047641
# std    3.384366e-04   0.018148   0.020714
# min    3.576521e-10   0.029691   0.016043
# 25%    7.271416e-06   0.058925   0.036584
# 50%    3.504271e-05   0.064563   0.046374
# 75%    3.343989e-04   0.074231   0.057478
# max    9.809590e-04   0.092770   0.086364

# %%
# Summarizer Review for all Sections
plot("../csv/summarizer_language_scores.csv")
# Out:
#             BLEU    ROUGE-L     METEOR
# count  10.000000  10.000000  10.000000
# mean    0.004641   0.092512   0.145579
# std     0.002587   0.024712   0.030838
# min     0.001834   0.046963   0.096826
# 25%     0.002906   0.080038   0.125883
# 50%     0.004029   0.086273   0.145023
# 75%     0.006099   0.110378   0.167742
# max     0.010226   0.128463   0.196070
